# %%
import fiftyone as fo

# %%
# The directory containing the source images
data_path = "../data/bmc/"

# The path to the COCO labels JSON file
labels_path = "../runs/labelme2coco/dataset.json"

# Import the dataset
dataset = fo.Dataset.from_dir(
    dataset_type=fo.types.COCODetectionDataset,
    data_path=data_path,
    labels_path=labels_path,
)
# Out:
#  100% |███████████████| 1082/1082 [43.7s elapsed, 0s remaining, 27.6 samples/s]

# %%
session = fo.launch_app(dataset)
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:5151/?context=ipython&subscription=8e8573dd-3812-4c1a-a5b5-0bd96b11281c"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ---

# %%
range_view2 = dataset[900:]

# %%
session = fo.launch_app(range_view2)
# Out:
# <style>
# @import url("https://fonts.googleapis.com/css2?family=Palanquin&display=swap");
#
# #focontainer-6b6d9c05-ba3d-4b1a-9910-32127897457f {
#   position: relative;
#   height: 800px;
#   display: block !important;
# }
# #foactivate-6b6d9c05-ba3d-4b1a-9910-32127897457f {
#   font-weight: bold;
#   cursor: pointer;
#   font-size: 24px;
#   border-radius: 3px;
#   text-align: center;
#   padding: 0.5em;
#   color: rgb(255, 255, 255);
#   font-family: "Palanquin", sans-serif;
#   position: absolute;
#   left: 50%;
#   top: 50%;
#   width: 160px;
#   margin-left: -80px;
#   margin-top: -23px;
#   background: hsla(210,11%,15%, 0.8);
#   border: none;
# }
# #foactivate-6b6d9c05-ba3d-4b1a-9910-32127897457f:focus {
#   outline: none;
# }
# #fooverlay-6b6d9c05-ba3d-4b1a-9910-32127897457f {
#   width: 100%;
#   height: 100%;
#   background: hsla(208, 7%, 46%, 0.7);
#   position: absolute;
#   top: 0;
#   left: 0;
#   display: none;
#   cursor: pointer;
# }
# </style>
#
# <div id="focontainer-6b6d9c05-ba3d-4b1a-9910-32127897457f">
#    <div id="fooverlay-6b6d9c05-ba3d-4b1a-9910-32127897457f" style="display: none;">
#       <button id="foactivate-6b6d9c05-ba3d-4b1a-9910-32127897457f" >Activate</button>
#    </div>
#    <img src='data:image/png;base64,...' style="width: 100%; max-width: 731px;"/>
# </div>
#
# <script type="text/javascript">
#    (function() {
#      var container = document.getElementById("focontainer-6b6d9c05-ba3d-4b1a-9910-32127897457f");
#      var overlay = document.getElementById("fooverlay-6b6d9c05-ba3d-4b1a-9910-32127897457f");
#      fetch(`http://localhost:5151/fiftyone`)
#      .then(() => {
#         overlay.addEventListener("click", () => {
#           fetch(`http://localhost:5151/event`, {
#             method: "POST",
#             body: JSON.stringify({
#               event: "reactivate_notebook_cell",
#               data: { subscription: "6b6d9c05-ba3d-4b1a-9910-32127897457f" },
#               subscription: "6b6d9c05-ba3d-4b1a-9910-32127897457f"
#             })
#           })
#         });
#         container.addEventListener("mouseenter", () => overlay.style.display = "block");
#         container.addEventListener("mouseleave", () => overlay.style.display = "none");
#      });
#    })();
# </script>
