# %%
import pandas as pd
import numpy as np
from glob import glob
import os
import shutil
from tqdm import tqdm
import json

# %% [markdown]
# ### 확장자 중복 처리

# %%
color_0=glob('./data/2022_10_preprocess/Color/color_0/*.jpg')
color_1=glob('./data/2022_10_preprocess/Color/color_1/*.jpg')
color_2=glob('./data/2022_10_preprocess/Color/color_2/*.jpg')


residue_0=glob('./data/2022_10_preprocess/Fecal_residue/Residue_0/*.jpg')
residue_1=glob('./data/2022_10_preprocess/Fecal_residue/Residue_1/*.jpg')
residue_2=glob('./data/2022_10_preprocess/Fecal_residue/Residue_2/*.jpg')

turbidity_0=glob('./data/2022_10_preprocess/turbidity/turbidity_0/*.jpg')
turbidity_2=glob('./data/2022_10_preprocess/turbidity/turbidity_2/*.jpg')

label_0=glob('./data/2022_10_preprocess/0/*.jpg')
label_1=glob('./data/2022_10_preprocess/1/*.jpg')
label_2=glob('./data/2022_10_preprocess/2/*.jpg')

colors_list = [color_0,color_1,color_2]
residue_list = [residue_0,residue_1,residue_2]
turbidity_list = [turbidity_0,turbidity_2]
label_list = [label_0,label_1,label_2]

for colors in colors_list:
    for file in colors:
        if file.split('\\')[1].split('.')[1] == 'jpg-1':
            print(file)
            os.rename(file, file.split('.jpg-1')[0]+'.jpg')
            os.rename('.'+file.split('.')[1]+'.jpg-1.json' ,file.split('.jpg-1')[0]+'.json') #json 파일 바꾸기
            
for residues in residue_list:
    for file in residues:
        if file.split('\\')[1].split('.')[1] == 'jpg-1':
            print(file)
            os.rename(file, file.split('.jpg-1')[0]+'.jpg')
            os.rename('.'+file.split('.')[1]+'.jpg-1.json' ,file.split('.jpg-1')[0]+'.json') #json 파일 바꾸기
            
for turbids in turbidity_list:
    for file in turbids:
        if file.split('\\')[1].split('.')[1] == 'jpg-1':
            print(file)
            os.rename(file, file.split('.jpg-1')[0]+'.jpg')
            os.rename('.'+file.split('.')[1]+'.jpg-1.json' ,file.split('.jpg-1')[0]+'.json') #json 파일 바꾸기

for labels in label_list:
    for file in labels:
        if file.split('\\')[1].split('.')[1] == 'jpg-1':
            print(file)
            os.rename(file, file.split('.jpg-1')[0]+'.jpg')
            os.rename('.'+file.split('.')[1]+'.jpg-1.json' ,file.split('.jpg-1')[0]+'.json') #json 파일 바꾸기

# %% [markdown]
# # 파일 라벨링 처리

# %%
print("label 0 : ",len(label_0))
print("label 1 : ",len(label_1))
print("label 2 : ",len(label_2))
print("총 샘플 수 :",len(label_0)+len(label_1)+len(label_2) )
# Out:
# label 0 :  334
# label 1 :  244
# label 2 :  329
# 총 샘플 수 : 907

# %%
print("color_0 : ",len(color_0))
print("color_1 : ",len(color_1))
print("color_2 : ",len(color_2))
print("총 샘플 수 :",len(color_0)+len(color_1)+len(color_2) )
# Out:
# color_0 :  205
# color_1 :  225
# color_2 :  916
# 총 샘플 수 : 1346

# %%
print("residue_0 : ",len(residue_0))
print("residue_1 : ",len(residue_1))
print("residue_2 : ",len(residue_2))
print("총 샘플 수 :",len(residue_0)+len(residue_1)+len(residue_2) )
# Out:
# residue_0 :  287
# residue_1 :  393
# residue_2 :  692
# 총 샘플 수 : 1372

# %%
print("turbidity_0 : ",len(turbidity_0))
print("turbidity_2 : ",len(turbidity_2))
print("총 샘플 수 :",len(turbidity_0)+len(turbidity_2))
# Out:
# turbidity_0 :  576
# turbidity_2 :  774
# 총 샘플 수 : 1350

# %% [markdown]
# ---
# ### 파일 목록 가져오기
# color 기준

# %%
from collections import defaultdict
image_list = defaultdict(lambda: [-1,-1,-1,-1]) #[color/Fecal_residue/turbidity/label]

# %% [markdown]
# ### Color

# %%
for val, colors in enumerate(colors_list):
    origin_names = [color.split("\\")[1].split('.')[0] for color in colors ]

    for name in origin_names:
        if(image_list[name][0] == -1):
            image_list[name][0] = val
        else:
            print("duplicated Color data!! : ", name, val)
            print("already value is : ", image_list[name][0])
# Out:
# duplicated Color data!! :  IMG_20220904_231628_1 2
# already value is :  1

# %% [markdown]
# ### Fecal_residue

# %%
for val, residues in enumerate(residue_list):
    origin_names = [residue.split("\\")[1].split('.')[0] for residue in residues ]

    for name in origin_names:
        if(image_list[name][1] == -1):
            image_list[name][1] = val
        else:
            print("duplicated Fecal_residue data!! : ", name, val)
            print("already value is : ", image_list[name][1])
# Out:
# duplicated Fecal_residue data!! :  IMG_20211119_012144_1 2
# already value is :  1
# duplicated Fecal_residue data!! :  IMG_20220724_223145 2
# already value is :  1

# %% [markdown]
# ### turbidity

# %%
for val, turbiditys in enumerate(turbidity_list):
    origin_names = [turbidity.split("\\")[1].split('.')[0] for turbidity in turbiditys]

    for name in origin_names:
        if(image_list[name][2] == -1):
            image_list[name][2] = val
        else:
            print("duplicated Turbidity data!! : ", name, val)
            print("already value is : ", image_list[name][0])

# %% [markdown]
# ### label

# %%
for val, labels in enumerate(label_list):
    origin_names = [label.split("\\")[1].split('.')[0] for label in labels]

    for name in origin_names:
        if(image_list[name][3] == -1):
            image_list[name][3] = val
        else:
            print("duplicated Label data!! : ", name, val)
            print("already value is : ", image_list[name][3])
# Out:
# duplicated Label data!! :  IMG_20210222_205946 2
# already value is :  1

# %% [markdown]
# ### pandas

# %%
df = {"origin_name":[], "color":[], "residue" : [], "turbidity":[], "label":[]}
not_enough_data = []
for key, val in image_list.items():
    if(-1 not in val):
        df["origin_name"].append(key)
        df["color"].append(val[0])
        df["residue"].append(val[1])
        df["turbidity"].append(val[2])
        df["label"].append(val[3])
    else:
        print("not enough data : ", key)
        print(val)
        not_enough_data.append(key)
df = pd.DataFrame.from_dict(df)
# Out:
# not enough data :  IMG_20191212_162004_1
# [0, 0, 0, -1]
# not enough data :  IMG_20200609_183930_1
# [0, 0, 0, -1]
# not enough data :  IMG_20200609_194904_1
# [0, 2, 0, -1]
# not enough data :  IMG_20201012_122724_1
# [0, 0, 0, -1]
# not enough data :  IMG_20201012_131515_1
# [0, 0, 0, -1]
# not enough data :  IMG_20201130_234558_1
# [0, 0, 0, -1]
# not enough data :  IMG_20201130_234605
# [0, 0, 0, -1]
# not enough data :  IMG_20201130_234605_1
# [0, 0, 0, -1]
# not enough data :  IMG_20201214_144119_1
# [0, 0, 0, -1]
# not enough data :  IMG_20210114_175603
# [0, 1, 0, -1]
# not enough data :  IMG_20210201_151510
# [0, 0, 0, -1]
# not enough data :  IMG_20210304_034244_1
# [0, 0, 0, -1]
# not enough data :  IMG_20210304_105147_1
# [0, 0, 0, -1]
# not enough data :  IMG_20210304_113345_1
# [0, 2, 0, -1]
# not enough data :  IMG_20210308_175708_1
# [0, 2, 0, -1]
# not enough data :  IMG_20210308_213938_1
# [0, 2, 0, -1]
# not enough data :  IMG_20210310_071840_1
# [0, 0, 0, -1]
# not enough data :  IMG_20210316_234244_1
# [0, 0, 0, -1]
# not enough data :  IMG_20210316_234252
# [0, 0, 0, -1]
# not enough data :  IMG_20210316_234252_1
# [0, 0, 0, -1]
# not enough data :  IMG_20210322_190014_1
# [0, 0, 0, -1]
# not enough data :  IMG_20210322_194304_1
# [0, 0, 0, -1]
# not enough data :  IMG_20210503_152700_1
# [0, 0, 0, -1]
# not enough data :  IMG_20210503_161818_1
# [0, 0, 0, -1]
# not enough data :  IMG_20210517_191001_1
# [0, 0, 0, -1]
# not enough data :  IMG_20210517_221902_1
# [0, 0, 0, -1]
# not enough data :  IMG_20210518_065116_1
# [0, 0, 0, -1]
# not enough data :  IMG_20210727_170200_1
# [0, 0, 0, -1]
# not enough data :  IMG_20210727_171425_1
# [0, 0, 0, -1]
# not enough data :  IMG_20210831_194716_1
# [0, 0, 0, -1]
# not enough data :  IMG_20210831_203317_1
# [0, 0, 0, -1]
# not enough data :  IMG_20210831_215124_1
# [0, 0, 0, -1]
# not enough data :  IMG_20210831_224141_1
# [0, 0, 0, -1]
# not enough data :  IMG_20210831_232241_1
# [0, 0, 0, -1]
# not enough data :  IMG_20210831_232252
# [0, 0, 0, -1]
# not enough data :  IMG_20210831_232252_1
# [0, 0, 0, -1]
# not enough data :  IMG_20210831_232259
# [0, 0, 0, -1]
# not enough data :  IMG_20210831_232259_1
# [0, 0, 0, -1]
# not enough data :  IMG_20210901_010418_1
# [0, 0, 0, -1]
# not enough data :  IMG_20210901_013139_1
# [0, 0, 0, -1]
# not enough data :  IMG_20210901_024405_1
# [0, 2, 0, -1]
# not enough data :  IMG_20210901_034606_1
# [0, 0, 0, -1]
# not enough data :  IMG_20210901_034613
# [0, 0, 0, -1]
# not enough data :  IMG_20210901_034613_1
# [0, 0, 0, -1]
# not enough data :  IMG_20210907_071459_1
# [0, 0, 0, -1]
# not enough data :  IMG_20210927_182422_1
# [0, 0, 0, -1]
# not enough data :  IMG_20211028_152117_1
# [0, 0, 0, -1]
# not enough data :  IMG_20211028_211022_1
# [0, 0, 0, -1]
# not enough data :  IMG_20211102_175824_1
# [0, 0, 0, -1]
# not enough data :  IMG_20211102_204450_1
# [0, 2, 0, -1]
# not enough data :  IMG_20211102_222137_1
# [0, 2, 0, -1]
# not enough data :  IMG_20211118_174146_1
# [0, 0, 0, -1]
# not enough data :  IMG_20211118_185117_1
# [0, 0, 0, -1]
# not enough data :  IMG_20211118_234151_1
# [0, 0, 0, -1]
# not enough data :  IMG_20211119_003148_1
# [0, 0, 0, -1]
# not enough data :  IMG_20211119_113329_1
# [0, 0, 0, -1]
# not enough data :  IMG_20211119_113335
# [0, 0, 0, -1]
# not enough data :  IMG_20211119_113335_1
# [0, 0, 0, -1]
# not enough data :  IMG_20211129_102404_1
# [0, 1, 0, -1]
# not enough data :  IMG_20211216_140637_1
# [0, 0, 0, -1]
# not enough data :  IMG_20211230_210230_1
# [0, 0, 0, -1]
# not enough data :  IMG_20220103_223105_1
# [0, 0, 0, -1]
# not enough data :  IMG_20220202_170453_1
# [0, 1, 0, -1]
# not enough data :  IMG_20220222_202546_1
# [0, 0, 0, -1]
# not enough data :  IMG_20220425_220134_1
# [0, 0, 0, -1]
# not enough data :  IMG_20220425_230440_1
# [0, 0, 0, -1]
# not enough data :  IMG_20220506_012354
# [0, -1, 0, 0]
# not enough data :  IMG_20220506_020439
# [0, -1, 0, 0]
# not enough data :  IMG_20220506_065546
# [0, -1, 0, 0]
# not enough data :  IMG_20220510_223431
# [0, -1, 0, 0]
# not enough data :  IMG_20220725_220907
# [0, -1, 0, 0]
# not enough data :  IMG_20220804_205738
# [0, -1, 0, 0]
# not enough data :  IMG_20220808_162214
# [0, -1, 0, 0]
# not enough data :  IMG_20220904_220058_1
# [0, 0, 0, -1]
# not enough data :  IMG_20221024_182236
# [0, -1, 0, -1]
# not enough data :  IMG_20221024_215601
# [0, -1, 0, 0]
# not enough data :  IMG_20190808_220818
# [1, 0, 0, -1]
# not enough data :  IMG_20191001_232608_1
# [1, 0, 0, -1]
# not enough data :  IMG_20191126_210515_1
# [1, 2, 0, -1]
# not enough data :  IMG_20191126_210554
# [1, 2, 0, -1]
# not enough data :  IMG_20191126_210554_1
# [1, 2, 0, -1]
# not enough data :  IMG_20191201_052138_1
# [1, 0, 0, -1]
# not enough data :  IMG_20191216_205400
# [1, 0, 0, -1]
# not enough data :  IMG_20191216_211840
# [1, 0, 0, -1]
# not enough data :  IMG_20191216_215922
# [1, 0, 0, -1]
# not enough data :  IMG_20200505_204102_1
# [1, 0, 0, -1]
# not enough data :  IMG_20200505_204108
# [1, 0, 0, -1]
# not enough data :  IMG_20200505_204108_1
# [1, 0, 0, -1]
# not enough data :  IMG_20200508_072821_1
# [1, 1, 0, -1]
# not enough data :  IMG_20201123_162613_1
# [1, 0, 0, -1]
# not enough data :  IMG_20201128_201727_1
# [1, 0, 0, -1]
# not enough data :  IMG_20201201_014656_1
# [1, 2, 0, -1]
# not enough data :  IMG_20201201_025737_1
# [1, 2, 0, -1]
# not enough data :  IMG_20210301_211526_1
# [1, 1, 0, -1]
# not enough data :  IMG_20210301_220757_1
# [1, 1, 0, -1]
# not enough data :  IMG_20210321_194133_1
# [1, 0, 1, -1]
# not enough data :  IMG_20210408_180455_1
# [1, 1, 0, -1]
# not enough data :  IMG_20210415_150214_1
# [1, 2, 0, -1]
# not enough data :  IMG_20210429_010001_1
# [1, 2, 0, -1]
# not enough data :  IMG_20210503_173624_1
# [1, 1, 0, -1]
# not enough data :  IMG_20210503_191139_1
# [1, 1, 0, -1]
# not enough data :  IMG_20210610_202143_1
# [1, 2, 0, -1]
# not enough data :  IMG_20210610_202147_1
# [1, 2, 0, -1]
# not enough data :  IMG_20210708_190005_1
# [1, 2, 0, -1]
# not enough data :  IMG_20210829_170351_1
# [1, 1, 0, -1]
# not enough data :  IMG_20210829_175036_1
# [1, 1, 0, -1]
# not enough data :  IMG_20210829_180512_1
# [1, 2, 0, -1]
# not enough data :  IMG_20210830_194305_1
# [1, 0, 0, -1]
# not enough data :  IMG_20210901_025331_1
# [1, 2, 0, -1]
# not enough data :  IMG_20210927_184429_1
# [1, 2, 0, -1]
# not enough data :  IMG_20211006_224706_1
# [1, 1, 0, -1]
# not enough data :  IMG_20211109_233117_1
# [1, 2, 0, -1]
# not enough data :  IMG_20211119_010755_1
# [1, 0, 0, -1]
# not enough data :  IMG_20211119_011129_1
# [1, 2, 0, -1]
# not enough data :  IMG_20211119_011457_1
# [1, 1, 0, -1]
# not enough data :  IMG_20211119_012144_1
# [1, 1, 0, -1]
# not enough data :  IMG_20211230_215128_1
# [1, 1, 0, -1]
# not enough data :  IMG_20220112_122817_1
# [1, 0, 0, -1]
# not enough data :  IMG_20220112_132824_1
# [1, 2, 0, -1]
# not enough data :  IMG_20220202_161159_1
# [1, 1, 0, -1]
# not enough data :  IMG_20220202_163242_1
# [1, 1, 0, -1]
# not enough data :  IMG_20220202_210734_1
# [1, 1, 0, -1]
# not enough data :  IMG_20220221_212615_1
# [1, 0, 0, -1]
# not enough data :  IMG_20220222_205343_1
# [1, 1, 0, -1]
# not enough data :  IMG_20220222_213723_1
# [1, 1, 0, -1]
# not enough data :  IMG_20220322_053627_1
# [1, 2, 0, -1]
# not enough data :  IMG_20220426_034108_1
# [1, 1, 0, -1]
# not enough data :  IMG_20220426_040144_1
# [1, 1, 0, -1]
# not enough data :  IMG_20220503_230302_1
# [1, -1, 0, -1]
# not enough data :  IMG_20220504_002259_1
# [1, 1, 1, -1]
# not enough data :  IMG_20220504_003149_1
# [1, 1, 1, -1]
# not enough data :  IMG_20220516_221935
# [1, -1, 1, 0]
# not enough data :  IMG_20220616_223452
# [1, 2, 1, -1]
# not enough data :  IMG_20220616_230558
# [1, 2, -1, 2]
# not enough data :  IMG_20220620_155613_1
# [1, 2, 1, -1]
# not enough data :  IMG_20220627_174424_1
# [1, 2, 0, -1]
# not enough data :  IMG_20220708_034340
# [1, -1, 1, 0]
# not enough data :  IMG_20220708_034343
# [1, -1, 1, -1]
# not enough data :  IMG_20220808_173412_1
# [1, 2, 0, -1]
# not enough data :  IMG_20220904_185346
# [1, 0, 0, -1]
# not enough data :  IMG_20220904_231628_1
# [1, 2, 0, -1]
# not enough data :  IMG_20220918_203226_1
# [1, 2, 0, -1]
# not enough data :  IMG_20221003_185834
# [1, 2, 0, -1]
# not enough data :  IMG_20221027_204853
# [1, 2, 0, -1]
# not enough data :  IMG_20190708_223340
# [2, 1, 0, -1]
# not enough data :  IMG_20191106_042340_1
# [2, 1, 1, -1]
# not enough data :  IMG_20191106_042341
# [2, 1, 1, -1]
# not enough data :  IMG_20191106_042341_1
# [2, 1, 1, -1]
# not enough data :  IMG_20191106_072121_1
# [2, 1, 1, -1]
# not enough data :  IMG_20191123_105829
# [2, 2, 1, -1]
# not enough data :  IMG_20191123_105829_1
# [2, 1, 1, -1]
# not enough data :  IMG_20191123_105920
# [2, 1, 1, -1]
# not enough data :  IMG_20191123_105920_1
# [2, 1, 1, -1]
# not enough data :  IMG_20191210_172320_1
# [2, 1, 1, -1]
# not enough data :  IMG_20191210_172324
# [2, 1, 1, -1]
# not enough data :  IMG_20191210_172324_1
# [2, 1, 1, -1]
# not enough data :  IMG_20191212_185630_1
# [2, 2, 1, -1]
# not enough data :  IMG_20191212_195650_1
# [2, 2, 1, -1]
# not enough data :  IMG_20191216_222624
# [2, 1, 1, -1]
# not enough data :  IMG_20191217_185216_1
# [2, 2, 0, -1]
# not enough data :  IMG_20191223_211233_1
# [2, 1, 1, -1]
# not enough data :  IMG_20200107_224654_1
# [2, 1, 0, -1]
# not enough data :  IMG_20200109_161559_1
# [2, 1, 1, -1]
# not enough data :  IMG_20200213_230426_1
# [2, 1, 1, -1]
# not enough data :  IMG_20200316_201303
# [2, 2, 1, -1]
# not enough data :  IMG_20200326_191344_1
# [2, 1, 0, -1]
# not enough data :  IMG_20200326_195840_1
# [2, 1, 0, -1]
# not enough data :  IMG_20200406_215748_1
# [2, 1, 0, -1]
# not enough data :  IMG_20200426_161213_1
# [2, 2, 0, -1]
# not enough data :  IMG_20200426_181326_1
# [2, 2, 1, -1]
# not enough data :  IMG_20200507_150745_1
# [2, 1, 0, -1]
# not enough data :  IMG_20200521_183121_1
# [2, 1, 0, -1]
# not enough data :  IMG_20200607_203252_1
# [2, 2, 1, -1]
# not enough data :  IMG_20200607_203300
# [2, 1, 1, -1]
# not enough data :  IMG_20200607_203300_1
# [2, 1, 1, -1]
# not enough data :  IMG_20200607_205256_1
# [2, 2, 1, -1]
# not enough data :  IMG_20200609_234713_1
# [2, 0, 0, -1]
# not enough data :  IMG_20200610_065839_1
# [2, 2, 1, -1]
# not enough data :  IMG_20200618_170733_1
# [2, 2, 1, -1]
# not enough data :  IMG_20200709_151926_1
# [2, 1, 1, -1]
# not enough data :  IMG_20200713_161950_1
# [2, 2, 0, -1]
# not enough data :  IMG_20200914_174434_1
# [2, 2, 1, -1]
# not enough data :  IMG_20200922_163315_1
# [2, 2, 1, -1]
# not enough data :  IMG_20201012_132706_1
# [2, 1, 1, -1]
# not enough data :  IMG_20201012_132712
# [2, 1, 1, -1]
# not enough data :  IMG_20201012_132712_1
# [2, 1, 1, -1]
# not enough data :  IMG_20201015_204928_1
# [2, 2, 1, -1]
# not enough data :  IMG_20201022_160230_1
# [2, 2, 1, -1]
# not enough data :  IMG_20201029_041348_1
# [2, 0, 1, -1]
# not enough data :  IMG_20201029_041353
# [2, 0, 1, -1]
# not enough data :  IMG_20201029_041353_1
# [2, 0, 1, -1]
# not enough data :  IMG_20201030_080518_1
# [2, 0, 1, -1]
# not enough data :  IMG_20201123_162049_1
# [2, 2, 1, -1]
# not enough data :  IMG_20201130_151022
# [2, 2, 1, -1]
# not enough data :  IMG_20201130_151022_1
# [2, 2, 1, -1]
# not enough data :  IMG_20201130_154402
# [2, 1, 1, -1]
# not enough data :  IMG_20201130_171433~2
# [2, 2, 1, -1]
# not enough data :  IMG_20201214_210902_1
# [2, 1, 1, -1]
# not enough data :  IMG_20210104_184259
# [2, 2, 1, -1]
# not enough data :  IMG_20210105_135206_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210105_175225_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210111_185328_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210111_193607_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210111_193617
# [2, 2, 1, -1]
# not enough data :  IMG_20210111_193617_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210118_160126_1
# [2, 1, 1, -1]
# not enough data :  IMG_20210125_182525_1
# [2, 1, 0, -1]
# not enough data :  IMG_20210125_194634_1
# [2, 1, 1, -1]
# not enough data :  IMG_20210128_131939_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210131_153726_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210131_185946_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210215_205041_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210225_190827_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210225_190833
# [2, 2, 1, -1]
# not enough data :  IMG_20210225_190833_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210301_220808_1
# [2, 1, 1, -1]
# not enough data :  IMG_20210303_161015_1
# [2, -1, 1, -1]
# not enough data :  IMG_20210303_230559_1
# [2, 0, 1, -1]
# not enough data :  IMG_20210304_004121_1
# [2, 0, 1, -1]
# not enough data :  IMG_20210304_004127
# [2, 0, 1, -1]
# not enough data :  IMG_20210304_004127_1
# [2, 0, 1, -1]
# not enough data :  IMG_20210304_013803_1
# [2, 0, 1, -1]
# not enough data :  IMG_20210304_032125_1
# [2, 1, 0, -1]
# not enough data :  IMG_20210304_130356_1
# [2, 1, 1, -1]
# not enough data :  IMG_20210304_171550_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210305_012352_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210305_064123_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210311_084545_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210311_194129_1
# [2, 1, 1, -1]
# not enough data :  IMG_20210311_194150
# [2, 1, 1, -1]
# not enough data :  IMG_20210311_194150_1
# [2, 1, 1, -1]
# not enough data :  IMG_20210312_104236_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210317_002710_1
# [2, 1, 0, -1]
# not enough data :  IMG_20210317_002720
# [2, 1, 0, -1]
# not enough data :  IMG_20210317_002720_1
# [2, 1, 0, -1]
# not enough data :  IMG_20210317_011715_1
# [2, 1, 0, -1]
# not enough data :  IMG_20210317_011742
# [2, 1, 0, -1]
# not enough data :  IMG_20210317_011742_1
# [2, 1, 0, -1]
# not enough data :  IMG_20210318_200123_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210318_215016_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210321_165414_1
# [2, 0, 1, -1]
# not enough data :  IMG_20210322_211617_1
# [2, 1, 0, -1]
# not enough data :  IMG_20210322_221405_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210322_230625_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210322_230822
# [2, 2, 1, -1]
# not enough data :  IMG_20210322_230822_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210325_144823_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210325_165540_1
# [2, 1, 0, -1]
# not enough data :  IMG_20210325_183833_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210325_185032_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210325_185036
# [2, 2, 1, -1]
# not enough data :  IMG_20210325_185036_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210325_191102_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210408_184102_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210415_214437_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210418_190527_1
# [2, 1, 1, -1]
# not enough data :  IMG_20210418_211808_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210420_174757_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210422_211621_1
# [2, 1, 0, -1]
# not enough data :  IMG_20210426_163553_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210503_202356_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210505_234525_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210505_234749
# [2, 2, 1, -1]
# not enough data :  IMG_20210505_234749_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210506_185737_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210506_204207_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210518_013141_1
# [2, 0, 0, -1]
# not enough data :  IMG_20210527_202207_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210527_214303_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210530_211425_1
# [2, 1, 1, -1]
# not enough data :  IMG_20210530_221519_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210530_221525
# [2, 2, 1, -1]
# not enough data :  IMG_20210530_221525_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210530_230149_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210607_213921_1
# [2, 1, 0, -1]
# not enough data :  IMG_20210607_222342_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210610_210811_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210610_210816
# [2, 2, 1, -1]
# not enough data :  IMG_20210610_210816_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210610_223715_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210617_213922_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210620_175248_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210620_175257
# [2, 2, 1, -1]
# not enough data :  IMG_20210620_175257_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210620_183720_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210624_183010_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210624_184856_1
# [2, 1, 1, -1]
# not enough data :  IMG_20210625_104844_1
# [2, 0, 1, -1]
# not enough data :  IMG_20210628_210537_1
# [2, 1, 1, -1]
# not enough data :  IMG_20210701_195103_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210701_205159_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210712_204643_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210712_230421_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210722_220513_1
# [2, 1, 1, -1]
# not enough data :  IMG_20210723_000417_1
# [2, 0, 1, -1]
# not enough data :  IMG_20210726_221228
# [2, 2, 1, -1]
# not enough data :  IMG_20210727_180853_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210815_194510_1
# [2, 1, 1, -1]
# not enough data :  IMG_20210815_202908_1
# [2, 1, 1, -1]
# not enough data :  IMG_20210819_184214_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210823_194132_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210829_185152_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210829_191029_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210829_191029_1~2
# [2, 2, 1, -1]
# not enough data :  IMG_20210829_201217_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210830_095321_1
# [2, 1, 1, -1]
# not enough data :  IMG_20210830_190819_1
# [2, 2, 0, -1]
# not enough data :  IMG_20210830_200956_1
# [2, 1, 1, -1]
# not enough data :  IMG_20210831_172820_1
# [2, 1, 1, -1]
# not enough data :  IMG_20210831_180844_1
# [2, 1, 1, -1]
# not enough data :  IMG_20210901_061143_1
# [2, 1, 1, -1]
# not enough data :  IMG_20210901_064924_1
# [2, 1, 0, -1]
# not enough data :  IMG_20210902_192140_1
# [2, 1, 1, -1]
# not enough data :  IMG_20210902_203207_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210914_193331_1
# [2, 1, 1, -1]
# not enough data :  IMG_20210914_212601_1
# [2, 2, 1, -1]
# not enough data :  IMG_20210916_184627_1
# [2, 1, 0, -1]
# not enough data :  IMG_20210916_193647_1
# [2, 1, 0, -1]
# not enough data :  IMG_20210916_201144_1
# [2, 1, 0, -1]
# not enough data :  IMG_20210927_175737_1
# [2, 1, 1, -1]
# not enough data :  IMG_20210927_200519_1
# [2, 1, 1, -1]
# not enough data :  IMG_20210930_215151_1
# [2, 1, 1, -1]
# not enough data :  IMG_20211004_193817_1
# [2, 2, 1, -1]
# not enough data :  IMG_20211004_205848_1
# [2, 2, 1, -1]
# not enough data :  IMG_20211005_201051_1
# [2, 2, 1, -1]
# not enough data :  IMG_20211006_212355_1
# [2, 1, 1, -1]
# not enough data :  IMG_20211006_231923_1
# [2, 2, 1, -1]
# not enough data :  IMG_20211007_214256_1
# [2, 2, 1, -1]
# not enough data :  IMG_20211007_221529_1
# [2, 2, 1, -1]
# not enough data :  IMG_20211007_221543
# [2, 2, 1, -1]
# not enough data :  IMG_20211007_221543_1
# [2, 2, 1, -1]
# not enough data :  IMG_20211012_193927_1
# [2, 1, 1, -1]
# not enough data :  IMG_20211012_235406_1
# [2, 1, 1, -1]
# not enough data :  IMG_20211019_222604_1
# [2, 1, 1, -1]
# not enough data :  IMG_20211019_225250_1
# [2, 2, 1, -1]
# not enough data :  IMG_20211028_213655_1
# [2, 2, 1, -1]
# not enough data :  IMG_20211031_173357_1
# [2, 2, 1, -1]
# not enough data :  IMG_20211031_173403
# [2, 2, 1, -1]
# not enough data :  IMG_20211031_173403_1
# [2, 2, 1, -1]
# not enough data :  IMG_20211102_191054_1
# [2, 2, 1, -1]
# not enough data :  IMG_20211108_185925_1
# [2, 1, 0, -1]
# not enough data :  IMG_20211110_001719_1
# [2, 2, 1, -1]
# not enough data :  IMG_20211117_215504_1
# [2, 1, 0, -1]
# not enough data :  IMG_20211117_224855_1
# [2, 2, 1, -1]
# not enough data :  IMG_20211117_232417_1
# [2, 2, 1, -1]
# not enough data :  IMG_20211117_232425
# [2, 2, 1, -1]
# not enough data :  IMG_20211117_232425_1
# [2, 2, 1, -1]
# not enough data :  IMG_20211118_224816_1
# [2, 1, 1, -1]
# not enough data :  IMG_20211119_004009_1
# [2, 1, 0, -1]
# not enough data :  IMG_20211119_013122_1
# [2, 1, 0, -1]
# not enough data :  IMG_20211119_123823_1
# [2, 1, 0, -1]
# not enough data :  IMG_20211129_110520_1
# [2, 1, 0, -1]
# not enough data :  IMG_20211129_202945_1
# [2, 2, 1, -1]
# not enough data :  IMG_20211129_212414_1
# [2, 2, 1, -1]
# not enough data :  IMG_20211209_192434_1
# [2, 2, 1, -1]
# not enough data :  IMG_20211209_201316_1
# [2, 2, 1, -1]
# not enough data :  IMG_20211213_175153_1
# [2, 2, 1, -1]
# not enough data :  IMG_20211214_171552_1
# [2, 1, 1, -1]
# not enough data :  IMG_20211214_191608_1
# [2, 1, 1, -1]
# not enough data :  IMG_20211214_205359_1
# [2, 2, 1, -1]
# not enough data :  IMG_20211221_221403_1
# [2, 2, 1, -1]
# not enough data :  IMG_20211221_230440_1
# [2, 2, 1, -1]
# not enough data :  IMG_20211230_195531_1
# [2, 1, 0, -1]
# not enough data :  IMG_20211230_195537
# [2, 1, 0, -1]
# not enough data :  IMG_20211230_195537_1
# [2, 1, 0, -1]
# not enough data :  IMG_20220102_202527_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220102_211542_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220103_113543_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220103_190520_1
# [2, 1, 1, -1]
# not enough data :  IMG_20220103_190524_1
# [2, 1, 1, -1]
# not enough data :  IMG_20220103_190530_1
# [2, 1, 1, -1]
# not enough data :  IMG_20220103_212235
# [2, 2, 1, -1]
# not enough data :  IMG_20220103_212801_1
# [2, 1, 1, -1]
# not enough data :  IMG_20220103_213148_1
# [2, 0, 1, -1]
# not enough data :  IMG_20220103_235639_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220104_005932_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220106_202738_1
# [2, 1, 0, -1]
# not enough data :  IMG_20220110_204114_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220110_210733_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220113_094556_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220113_115700_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220113_131144_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220114_081116
# [2, 1, 1, -1]
# not enough data :  IMG_20220118_233628_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220202_135832_1
# [2, 1, 1, -1]
# not enough data :  IMG_20220202_142004_1
# [2, 1, 1, -1]
# not enough data :  IMG_20220202_181715_1
# [2, 1, 0, -1]
# not enough data :  IMG_20220202_215305_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220203_180816
# [2, 2, 1, -1]
# not enough data :  IMG_20220208_184927_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220208_200727_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220208_203524_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220208_210255_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220208_214433_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220208_220252_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220208_231922_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220221_185422_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220221_234957_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220222_174336
# [2, 2, 0, -1]
# not enough data :  IMG_20220222_180205
# [2, 1, 0, -1]
# not enough data :  IMG_20220222_221953_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220223_080655_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220223_084208_1
# [2, 1, 0, -1]
# not enough data :  IMG_20220315_065025
# [2, 2, 1, -1]
# not enough data :  IMG_20220327_203152_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220328_190306_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220329_153709_1
# [2, 1, 1, -1]
# not enough data :  IMG_20220329_165317_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220411_182708
# [2, 0, 1, -1]
# not enough data :  IMG_20220411_192257
# [2, 0, 1, -1]
# not enough data :  IMG_20220418_063510
# [2, 1, 1, -1]
# not enough data :  IMG_20220419_232248_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220425_172344_1
# [2, 0, 1, -1]
# not enough data :  IMG_20220426_000942_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220426_043652_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220426_043658
# [2, 2, 1, -1]
# not enough data :  IMG_20220426_043658_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220426_045612_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220426_045835
# [2, 2, 1, -1]
# not enough data :  IMG_20220426_045835_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220426_045843
# [2, 2, 1, -1]
# not enough data :  IMG_20220426_045843_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220426_051924_1
# [2, 2, 0, -1]
# not enough data :  IMG_20220426_052303_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220426_052310
# [2, 2, 1, -1]
# not enough data :  IMG_20220426_052310_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220426_055724_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220426_060233_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220426_060239
# [2, 2, 1, -1]
# not enough data :  IMG_20220426_060239_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220426_061454_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220426_061459
# [2, 2, 1, -1]
# not enough data :  IMG_20220426_061459_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220426_091645_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220426_091731
# [2, 2, 1, -1]
# not enough data :  IMG_20220426_091731_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220426_103521_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220426_194419_1
# [2, 1, 0, -1]
# not enough data :  IMG_20220426_201934_1
# [2, 1, 1, -1]
# not enough data :  IMG_20220426_203317_1
# [2, 1, 1, -1]
# not enough data :  IMG_20220426_214229_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220427_040619_1
# [2, 0, 0, -1]
# not enough data :  IMG_20220427_043020_1
# [2, 0, 1, -1]
# not enough data :  IMG_20220428_221121_1
# [2, 1, 1, -1]
# not enough data :  IMG_20220428_234856_1
# [2, 1, 1, -1]
# not enough data :  IMG_20220502_235641
# [2, 1, 1, -1]
# not enough data :  IMG_20220503_110039_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220503_183205
# [2, -1, 1, 0]
# not enough data :  IMG_20220503_205903_1
# [2, 1, 0, -1]
# not enough data :  IMG_20220503_230302
# [2, -1, 0, 0]
# not enough data :  IMG_20220503_235744_1
# [2, 1, 0, -1]
# not enough data :  IMG_20220503_235748
# [2, 1, 0, -1]
# not enough data :  IMG_20220503_235748_1
# [2, 1, 0, -1]
# not enough data :  IMG_20220504_010351_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220512_094808
# [2, -1, 1, 0]
# not enough data :  IMG_20220516_202540
# [2, 2, 1, -1]
# not enough data :  IMG_20220523_200545_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220523_204940_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220616_201103_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220616_214505
# [2, 2, 1, -1]
# not enough data :  IMG_20220616_220220
# [2, 2, 1, -1]
# not enough data :  IMG_20220620_172008_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220627_224354
# [2, 1, 1, -1]
# not enough data :  IMG_20220629_174023_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220629_183649_1
# [2, 1, 1, -1]
# not enough data :  IMG_20220629_190213_1
# [2, 1, 1, -1]
# not enough data :  IMG_20220629_195532_1
# [2, 1, 1, -1]
# not enough data :  IMG_20220725_000952
# [2, 2, 1, -1]
# not enough data :  IMG_20220726_204350
# [2, 1, 1, -1]
# not enough data :  IMG_20220731_155334_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220731_173813_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220731_210227
# [2, 2, -1, 1]
# not enough data :  IMG_20220807_194831_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220808_181136_1
# [2, 2, 0, -1]
# not enough data :  IMG_20220808_212055_1
# [2, 1, 1, -1]
# not enough data :  IMG_20220818_221353_1
# [2, 2, 0, -1]
# not enough data :  IMG_20220818_221359
# [2, 2, 0, -1]
# not enough data :  IMG_20220818_221359_1
# [2, 2, 0, -1]
# not enough data :  IMG_20220818_231253_1
# [2, 1, 0, -1]
# not enough data :  IMG_20220818_231258
# [2, 1, 0, -1]
# not enough data :  IMG_20220818_231258_1
# [2, 1, 0, -1]
# not enough data :  IMG_20220818_233809_1
# [2, 2, 1, -1]
# not enough data :  IMG_20220819_112307
# [2, -1, 1, 1]
# not enough data :  IMG_20220819_112307_1
# [2, 1, 1, -1]
# not enough data :  IMG_20220822_213506
# [2, 2, 1, -1]
# not enough data :  IMG_20220831_001207
# [2, 2, 1, -1]
# not enough data :  IMG_20220904_212121
# [2, 2, 1, -1]
# not enough data :  IMG_20220904_225053_1
# [2, 1, 0, -1]
# not enough data :  IMG_20220912_190309_1
# [2, 1, -1, -1]
# not enough data :  IMG_20220916_040722
# [2, 2, 1, -1]
# not enough data :  IMG_20220921_223416
# [2, 2, 0, -1]
# not enough data :  IMG_20221007_013722_1
# [2, 1, 1, -1]
# not enough data :  IMG_20221014_032509
# [2, 2, 1, -1]
# not enough data :  PANO_20200407_221527
# [2, 2, 1, -1]
# not enough data :  IMG_20220502_231528
# [-1, 0, -1, 0]
# not enough data :  IMG_20220503_055138
# [-1, 0, -1, 0]
# not enough data :  IMG_20220506_035106
# [-1, 0, -1, 0]
# not enough data :  IMG_20220506_054002
# [-1, 0, -1, 0]
# not enough data :  IMG_20220610_203211
# [-1, 0, -1, 0]
# not enough data :  IMG_20220610_203219
# [-1, 0, -1, -1]
# not enough data :  IMG_20220626_145239
# [-1, 0, -1, 0]
# not enough data :  IMG_20220626_150644
# [-1, 0, -1, 0]
# not enough data :  IMG_20220626_160125
# [-1, 0, -1, 0]
# not enough data :  IMG_20220626_160815
# [-1, 0, -1, 0]
# not enough data :  IMG_20220731_195627
# [-1, 0, -1, 0]
# not enough data :  IMG_20220731_200803
# [-1, 0, -1, 0]
# not enough data :  IMG_20220731_201208
# [-1, 0, -1, 0]
# not enough data :  IMG_20220731_201724
# [-1, 0, -1, 0]
# not enough data :  IMG_20220804_195213
# [-1, 0, -1, 0]
# not enough data :  IMG_20220808_162214_1
# [-1, 0, -1, -1]
# not enough data :  IMG_20220808_163151
# [-1, 0, -1, 0]
# not enough data :  IMG_20220808_163151_1
# [-1, 0, -1, -1]
# not enough data :  IMG_20220828_221250
# [-1, 0, -1, 0]
# not enough data :  IMG_20220828_221256
# [-1, 0, -1, -1]
# not enough data :  IMG_20220916_003301
# [-1, 0, -1, 0]
# not enough data :  IMG_20220916_003301_1
# [-1, 0, -1, -1]
# not enough data :  IMG_20220916_024141
# [-1, 0, -1, 0]
# not enough data :  IMG_20220916_024141_1
# [-1, 0, -1, -1]
# not enough data :  IMG_20220922_075715
# [-1, 0, -1, 0]
# not enough data :  IMG_20220923_071504
# [-1, 0, -1, 0]
# not enough data :  IMG_20220923_112623
# [-1, 0, -1, 0]
# not enough data :  IMG_20221006_204234
# [-1, 0, -1, 0]
# not enough data :  IMG_20221006_213537
# [-1, 0, -1, 0]
# not enough data :  IMG_20221006_222115
# [-1, 0, -1, 0]
# not enough data :  IMG_20221006_224823
# [-1, 0, -1, 0]
# not enough data :  IMG_20221017_175635
# [-1, 0, -1, 0]
# not enough data :  IMG_20221024_154908
# [-1, 0, -1, 0]
# not enough data :  IMG_20221027_190827
# [-1, 0, -1, 0]
# not enough data :  IMG_20221027_193642
# [-1, 0, -1, 0]
# not enough data :  IMG_20221027_193645
# [-1, 0, -1, -1]
# not enough data :  IMG_20221004_184036
# [-1, 1, -1, 0]
# not enough data :  IMG_20221007_011402
# [-1, 1, -1, 0]
# not enough data :  IMG_20221007_011402_1
# [-1, 1, -1, -1]
# not enough data :  IMG_20221007_023913
# [-1, 1, -1, 0]
# not enough data :  IMG_20221007_023913_1
# [-1, 1, -1, -1]
# not enough data :  IMG_20221020_234655
# [-1, 1, -1, 0]
# not enough data :  IMG_20220808_173412
# [-1, 2, 0, 1]
# not enough data :  IMG_20200510_205628
# [-1, -1, 0, 0]
# not enough data :  IMG_20220626_195118
# [-1, -1, 0, 0]
# not enough data :  IMG_20220626_210703
# [-1, -1, 0, 0]
# not enough data :  IMG_20220626_214056
# [-1, -1, 0, 0]
# not enough data :  IMG_20220808_185326_1
# [-1, -1, 0, -1]
# not enough data :  IMG_20220808_202325_1
# [-1, -1, 0, -1]
# not enough data :  IMG_20200510_213649
# [-1, -1, 1, 0]

# %%
df.to_csv("./bmc_until10_preprocess.csv")
df
# Out:
#               origin_name  color  residue  turbidity  label
# 0            1301837407-1      0        0          0      0
# 1            1411450810-1      0        0          0      0
# 2            1651193832-1      0        0          0      0
# 3            2077897036-1      0        0          0      0
# 4             290980310-1      0        1          0      0
# ..                    ...    ...      ...        ...    ...
# 846   IMG_20221027_232100      2        2          0      2
# 847  PANO_20200407_221523      2        2          1      2
# 848  PANO_20200818_174909      2        2          1      2
# 849  PANO_20210330_062718      2        2          1      2
# 850     tmp_1610355667809      2        2          1      2
#
# [851 rows x 5 columns]

# %% [markdown]
# 여기 위까지만 실행됬다.
#
# ### 파일명 변경

# %%
# color 기준
DATASET_PATH = './data/2022_10_preprocess/Color'
NEW_PATH = './data/bmc_label_until-10-preprocess/'

# %%
os.makedirs(NEW_PATH, exist_ok=True)

# %%
folders = os.listdir(DATASET_PATH)
for idx, val in tqdm(df.iterrows()):
    if(val["color"] == 0):
        copy_from = os.path.join(DATASET_PATH, folders[0], val['origin_name'])
    elif(val["color"] == 1):
        copy_from = os.path.join(DATASET_PATH, folders[1], val['origin_name'])
    else:
        copy_from = os.path.join(DATASET_PATH, folders[2], val['origin_name'])
    copy_to = NEW_PATH + f'/{idx:04}.jpg'
    shutil.copyfile(copy_from + ".jpg", copy_to)
    #copy_to = NEW_PATH + f'/{idx:04}.json'
    #shutil.copyfile(copy_from + ".json", copy_to)
# Out:
# 851it [00:39, 21.57it/s]

# %% [markdown]
# ### json 수정

# %%
bmc_json = glob(NEW_PATH + '*.json')

for idx, val in tqdm(enumerate(bmc_json)):
    with open(val, 'r', encoding='utf-8') as f:
        json_data = json.load(f)
    
    json_data["imagePath"] = val[-9:-5] + '.jpg'
    json_data["imagePath"] = val[-9:-5] + '.jpg'
    json_data["shapes"][0]["label"] = str(df.iloc[idx]["label"])
    
    with open(val, 'w', encoding='utf-8') as f:
        json.dump(json_data, f, indent="\t")
# Out:
# 0it [00:00, ?it/s]

# %% [markdown]
# ### labelme to coco format (for fiftyone)

# %%
# import package
import labelme2coco

# set directory that contains labelme annotations and image files
labelme_folder = "./data/bmc_label_until-10/"

# set export dir
export_dir = "./data/dataset05-10"

# set train split rate
train_split_rate = 0.85

# convert labelme annotations to coco
labelme2coco.convert(labelme_folder, export_dir)#, train_split_rate)
# Out:
# There are 0 listed files in folder ./data/bmc_label_05-10/.
# Converting labelme annotations to COCO format: 0it [00:00, ?it/s]
# 12/12/2022 11:42:51 - INFO - labelme2coco -   Converted annotations in COCO format is exported to data\dataset05-10\dataset.json

# %%
# !python ./labelme2voc.py C:\Users\mai\Bowel_Movement_Cleaness\data\bmc_label_05-10 C:\Users\mai\Bowel_Movement_Cleaness\data\bmc_label_05-10_voc --labels labels.txt
# Out:
# python: can't open file 'd:\project\Bowel_Movement_Cleaness\labelme2voc.py': [Errno 2] No such file or directory
